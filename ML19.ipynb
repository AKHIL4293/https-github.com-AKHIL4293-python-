# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6]
y = [1,2,3,4,5,6]

plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Our First Plot')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6]
y = [2,5,6,4,7,8]

plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Our First Plot')
plt.show()
